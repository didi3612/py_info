# %% [markdown]
# ### <mark>json 檔案<mark>

# %%
# [{"label": "H7", "shape": [[1, 0, 1], [1, 1, 1], [1, 0, 1]], "order": "7", "color_hex": "#FF0000", "color_name": "red"}, {"label": "O6", "shape": [[1, 1, 1], [1, 1, 1]], "order": "6", "color_hex": "#DBFF2F", "color_name": "greenyellow"}, {"label": "F5", "shape": [[1, 1, 0], [0, 1, 1], [0, 1, 0]], "order": "5", "color_hex": "#EE82EE", "color_name": "violet"}, {"label": "Y5", "shape": [[1, 1, 1, 1], [0, 1, 0, 0]], "order": "5", "color_hex": "#00FF00", "color_name": "lime"}, {"label": "V5", "shape": [[1, 1, 1], [1, 0, 0], [1, 0, 0]], "order": "5", "color_hex": "#FFC0CB", "color_name": "pink"}, {"label": "U5", "shape": [[1, 0, 1], [1, 1, 1]], "order": "5", "color_hex": "#0000FF", "color_name": "blue"}, {"label": "N5", "shape": [[1, 1, 1, 0], [0, 0, 1, 1]], "order": "5", "color_hex": "#FF8C00", "color_name": "darkorange"}, {"label": "L5", "shape": [[1, 1, 1, 1], [1, 0, 0, 0]], "order": "5", "color_hex": "#008000", "color_name": "green"}, {"label": "Z5", "shape": [[1, 1, 0], [0, 1, 0], [0, 1, 1]], "order": "5", "color_hex": "#FFFF00", "color_name": "yellow"}, {"label": "O4", "shape": [[1, 1], [1, 1]], "order": "4", "color_hex": "#FFD700", "color_name": "gold"}, {"label": "T4", "shape": [[1, 1, 1], [0, 1, 0]], "order": "4", "color_hex": "#800080", "color_name": "purple"}, {"label": "Z4", "shape": [[1, 1, 0], [0, 1, 1]], "order": "4", "color_hex": "#00FFFF", "color_name": "cyan"}, {"label": "L4", "shape": [[1, 1, 1], [1, 0, 0]], "order": "4", "color_hex": "#00BFFF", "color_name": "deepskyblue"}]

# %% [markdown]
# ### <mark>H單一圖形<mark>

# %%
import re
import matplotlib.pyplot as plt

# 假设你的数据字符串
data_str = "H7:[[1,0,1],[1,1,1],[1,0,1]],#FF0000,red"

# 使用正则表达式提取数据
matches = re.match(r"(\w+):(\[\[.*\]\]),#(\w+),(\w+)", data_str)

if matches:
    label = matches.group(1)
    shape_str = matches.group(2)
    color_hex = "#" + matches.group(3)
    color_name = matches.group(4)

    # 提取形状数据
    shape = eval(shape_str)
    shape_height = len(shape)
    shape_width = len(shape[0])

    # 创建一个新的图形，根据形状的大小计算图形的大小
    fig, ax = plt.subplots(figsize=(shape_width, shape_height))

    # 绘制形状
    for i in range(len(shape)):
        for j in range(len(shape[0])):
            if shape[i][j] == 1:
                ax.add_patch(plt.Rectangle((j, i), 1, 1, color=color_hex))

    # 添加标签
    ax.text(0.5, 0.95, label, horizontalalignment='center', verticalalignment='top', transform=ax.transAxes)

    # 设置坐标轴
    ax.set_xlim(0, shape_width)
    ax.set_ylim(0, shape_height)
    ax.axis('off')  # 关闭坐标轴

    # 显示图形
    plt.show()
else:
    print("Invalid data format.")

# %% [markdown]
# ### <mark>全部圖形依序<mark>

# %%
import matplotlib.pyplot as plt
import ast

# 你的数据字符串
data_str = '[{"label": "H7", "shape": [[1, 0, 1], [1, 1, 1], [1, 0, 1]], "order": "7", "color_hex": "#FF0000", "color_name": "red"}, {"label": "O6", "shape": [[1, 1, 1], [1, 1, 1]], "order": "6", "color_hex": "#DBFF2F", "color_name": "greenyellow"}, {"label": "F5", "shape": [[1, 1, 0], [0, 1, 1], [0, 1, 0]], "order": "5", "color_hex": "#EE82EE", "color_name": "violet"}, {"label": "Y5", "shape": [[1, 1, 1, 1], [0, 1, 0, 0]], "order": "5", "color_hex": "#00FF00", "color_name": "lime"}, {"label": "V5", "shape": [[1, 1, 1], [1, 0, 0], [1, 0, 0]], "order": "5", "color_hex": "#FFC0CB", "color_name": "pink"}, {"label": "U5", "shape": [[1, 0, 1], [1, 1, 1]], "order": "5", "color_hex": "#0000FF", "color_name": "blue"}, {"label": "N5", "shape": [[1, 1, 1, 0], [0, 0, 1, 1]], "order": "5", "color_hex": "#FF8C00", "color_name": "darkorange"}, {"label": "L5", "shape": [[1, 1, 1, 1], [1, 0, 0, 0]], "order": "5", "color_hex": "#008000", "color_name": "green"}, {"label": "Z5", "shape": [[1, 1, 0], [0, 1, 0], [0, 1, 1]], "order": "5", "color_hex": "#FFFF00", "color_name": "yellow"}, {"label": "O4", "shape": [[1, 1], [1, 1]], "order": "4", "color_hex": "#FFD700", "color_name": "gold"}, {"label": "T4", "shape": [[1, 1, 1], [0, 1, 0]], "order": "4", "color_hex": "#800080", "color_name": "purple"}, {"label": "Z4", "shape": [[1, 1, 0], [0, 1, 1]], "order": "4", "color_hex": "#00FFFF", "color_name": "cyan"}, {"label": "L4", "shape": [[1, 1, 1], [1, 0, 0]], "order": "4", "color_hex": "#00BFFF", "color_name": "deepskyblue"}]'

# 将字符串转换为字典列表
data_list = ast.literal_eval(data_str)

# 遍历每个形状并绘制
for shape_info in data_list:
    label = shape_info['label']
    shape = shape_info['shape']
    color_hex = shape_info['color_hex']

    # 提取形状大小
    shape_height = len(shape)
    shape_width = len(shape[0])

    # 创建一个新的图形，根据形状的大小计算图形的大小
    fig, ax = plt.subplots(figsize=(shape_width, shape_height))

    # 绘制形状
    for i in range(len(shape)):
        for j in range(len(shape[0])):
            if shape[i][j] == 1:
                ax.add_patch(plt.Rectangle((j, i), 1, 1, color=color_hex))

    # 添加标签
    ax.text(0.5, 0.95, label, horizontalalignment='center', verticalalignment='top', transform=ax.transAxes)

    # 设置坐标轴
    ax.set_xlim(0, shape_width)
    ax.set_ylim(0, shape_height)
    ax.axis('off')  # 关闭坐标轴

    # 显示图形
    plt.show()

# %%
import ast

# 假设你的数据字符串
data_str = '[{"label": "H7", "shape": [[1, 0, 1], [1, 1, 1], [1, 0, 1]], "order": "7", "color_hex": "#FF0000", "color_name": "red"}, {"label": "O6", "shape": [[1, 1, 1], [1, 1, 1]], "order": "6", "color_hex": "#DBFF2F", "color_name": "greenyellow"}, {"label": "F5", "shape": [[1, 1, 0], [0, 1, 1], [0, 1, 0]], "order": "5", "color_hex": "#EE82EE", "color_name": "violet"}, {"label": "Y5", "shape": [[1, 1, 1, 1], [0, 1, 0, 0]], "order": "5", "color_hex": "#00FF00", "color_name": "lime"}, {"label": "V5", "shape": [[1, 1, 1], [1, 0, 0], [1, 0, 0]], "order": "5", "color_hex": "#FFC0CB", "color_name": "pink"}, {"label": "U5", "shape": [[1, 0, 1], [1, 1, 1]], "order": "5", "color_hex": "#0000FF", "color_name": "blue"}, {"label": "N5", "shape": [[1, 1, 1, 0], [0, 0, 1, 1]], "order": "5", "color_hex": "#FF8C00", "color_name": "darkorange"}, {"label": "L5", "shape": [[1, 1, 1, 1], [1, 0, 0, 0]], "order": "5", "color_hex": "#008000", "color_name": "green"}, {"label": "Z5", "shape": [[1, 1, 0], [0, 1, 0], [0, 1, 1]], "order": "5", "color_hex": "#FFFF00", "color_name": "yellow"}, {"label": "O4", "shape": [[1, 1], [1, 1]], "order": "4", "color_hex": "#FFD700", "color_name": "gold"}, {"label": "T4", "shape": [[1, 1, 1], [0, 1, 0]], "order": "4", "color_hex": "#800080", "color_name": "purple"}, {"label": "Z4", "shape": [[1, 1, 0], [0, 1, 1]], "order": "4", "color_hex": "#00FFFF", "color_name": "cyan"}, {"label": "L4", "shape": [[1, 1, 1], [1, 0, 0]], "order": "4", "color_hex": "#00BFFF", "color_name": "deepskyblue"}]'

# 将字符串转换为字典列表
data_list = ast.literal_eval(data_str)

# 统计图形数量
num_shapes = len(data_list)
print("总共有", num_shapes, "个图形。")
# Out:
# 总共有 13 个图形。

# %% [markdown]
# ### <mark>4x4繪圖<mark>

# %%
import matplotlib.pyplot as plt
import ast

# 假设你的数据字符串
data_str = '[{"label": "H7", "shape": [[1, 0, 1], [1, 1, 1], [1, 0, 1]], "order": "7", "color_hex": "#FF0000", "color_name": "red"}, {"label": "O6", "shape": [[1, 1, 1], [1, 1, 1]], "order": "6", "color_hex": "#DBFF2F", "color_name": "greenyellow"}, {"label": "F5", "shape": [[1, 1, 0], [0, 1, 1], [0, 1, 0]], "order": "5", "color_hex": "#EE82EE", "color_name": "violet"}, {"label": "Y5", "shape": [[1, 1, 1, 1], [0, 1, 0, 0]], "order": "5", "color_hex": "#00FF00", "color_name": "lime"}, {"label": "V5", "shape": [[1, 1, 1], [1, 0, 0], [1, 0, 0]], "order": "5", "color_hex": "#FFC0CB", "color_name": "pink"}, {"label": "U5", "shape": [[1, 0, 1], [1, 1, 1]], "order": "5", "color_hex": "#0000FF", "color_name": "blue"}, {"label": "N5", "shape": [[1, 1, 1, 0], [0, 0, 1, 1]], "order": "5", "color_hex": "#FF8C00", "color_name": "darkorange"}, {"label": "L5", "shape": [[1, 1, 1, 1], [1, 0, 0, 0]], "order": "5", "color_hex": "#008000", "color_name": "green"}, {"label": "Z5", "shape": [[1, 1, 0], [0, 1, 0], [0, 1, 1]], "order": "5", "color_hex": "#FFFF00", "color_name": "yellow"}, {"label": "O4", "shape": [[1, 1], [1, 1]], "order": "4", "color_hex": "#FFD700", "color_name": "gold"}, {"label": "T4", "shape": [[1, 1, 1], [0, 1, 0]], "order": "4", "color_hex": "#800080", "color_name": "purple"}, {"label": "Z4", "shape": [[1, 1, 0], [0, 1, 1]], "order": "4", "color_hex": "#00FFFF", "color_name": "cyan"}, {"label": "L4", "shape": [[1, 1, 1], [1, 0, 0]], "order": "4", "color_hex": "#00BFFF", "color_name": "deepskyblue"}]'

# 将字符串转换为字典列表
data_list = ast.literal_eval(data_str)

# 计算子图的行数和列数
num_rows = 4
num_cols = 4

# 创建一个新的图形，指定子图布局
fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, 12))

# 遍历每个形状并绘制
for i, shape_info in enumerate(data_list):
    row = i // num_cols
    col = i % num_cols

    label = shape_info['label']
    shape = shape_info['shape']
    color_hex = shape_info['color_hex']

    # 提取形状大小
    shape_height = len(shape)
    shape_width = len(shape[0])

    # 绘制形状
    for j in range(len(shape)):
        for k in range(len(shape[0])):
            if shape[j][k] == 1:
                axs[row, col].add_patch(plt.Rectangle((k, j), 1, 1, color=color_hex))

    # 添加标签
    axs[row, col].text(0.5, 0.95, label, horizontalalignment='center', verticalalignment='top', transform=axs[row, col].transAxes)

    # 设置子图的坐标轴
    axs[row, col].set_xlim(0, shape_width)
    axs[row, col].set_ylim(0, shape_height)
    axs[row, col].axis('off')  # 关闭子图的坐标轴

# 调整子图之间的间距
plt.tight_layout()

# 显示图形
plt.show()

# %% [markdown]
# ### <mark>O號黑底<mark>

# %%
import matplotlib.pyplot as plt
import ast

# 假设你的数据字符串
data_str = '[{"label": "H7", "shape": [[1, 0, 1], [1, 1, 1], [1, 0, 1]], "order": "7", "color_hex": "#FF0000", "color_name": "red"}, {"label": "O6", "shape": [[1, 1, 1], [1, 1, 1]], "order": "6", "color_hex": "#DBFF2F", "color_name": "greenyellow"}, {"label": "F5", "shape": [[1, 1, 0], [0, 1, 1], [0, 1, 0]], "order": "5", "color_hex": "#EE82EE", "color_name": "violet"}, {"label": "Y5", "shape": [[1, 1, 1, 1], [0, 1, 0, 0]], "order": "5", "color_hex": "#00FF00", "color_name": "lime"}, {"label": "V5", "shape": [[1, 1, 1], [1, 0, 0], [1, 0, 0]], "order": "5", "color_hex": "#FFC0CB", "color_name": "pink"}, {"label": "U5", "shape": [[1, 0, 1], [1, 1, 1]], "order": "5", "color_hex": "#0000FF", "color_name": "blue"}, {"label": "N5", "shape": [[1, 1, 1, 0], [0, 0, 1, 1]], "order": "5", "color_hex": "#FF8C00", "color_name": "darkorange"}, {"label": "L5", "shape": [[1, 1, 1, 1], [1, 0, 0, 0]], "order": "5", "color_hex": "#008000", "color_name": "green"}, {"label": "Z5", "shape": [[1, 1, 0], [0, 1, 0], [0, 1, 1]], "order": "5", "color_hex": "#FFFF00", "color_name": "yellow"}, {"label": "O4", "shape": [[1, 1], [1, 1]], "order": "4", "color_hex": "#FFD700", "color_name": "gold"}, {"label": "T4", "shape": [[1, 1, 1], [0, 1, 0]], "order": "4", "color_hex": "#800080", "color_name": "purple"}, {"label": "Z4", "shape": [[1, 1, 0], [0, 1, 1]], "order": "4", "color_hex": "#00FFFF", "color_name": "cyan"}, {"label": "L4", "shape": [[1, 1, 1], [1, 0, 0]], "order": "4", "color_hex": "#00BFFF", "color_name": "deepskyblue"}]'

# 将字符串转换为字典列表
data_list = ast.literal_eval(data_str)

# 计算子图的行数和列数
num_rows = 4
num_cols = 4

# 检查数据列表长度是否大于子图数量
if len(data_list) > num_rows * num_cols:
    raise ValueError("数据列表中的图形数量超出了子图布局的总数！")

# 创建一个新的图形，指定子图布局
fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, 12))

# 遍历每个形状并绘制
for i, shape_info in enumerate(data_list):
    row = i // num_cols
    col = i % num_cols

    label = shape_info['label']
    shape = shape_info['shape']
    color_hex = shape_info['color_hex']

    # 提取形状大小
    shape_height = len(shape)
    shape_width = len(shape[0])

    # 绘制形状
    for j in range(len(shape)):
        for k in range(len(shape[0])):
            if shape[j][k] == 1:
                # 正确绘制矩形
                axs[row, col].add_patch(plt.Rectangle((k, shape_height - 1 - j), 1, 1, color=color_hex))
            else:
                # 填充 0 的部分为黑色
                axs[row, col].add_patch(plt.Rectangle((k, shape_height - 1 - j), 1, 1, color='black'))

    # 添加标签
    axs[row, col].text(0.5, 0.95, label, horizontalalignment='center', verticalalignment='top', transform=axs[row, col].transAxes)

    # 设置子图的坐标轴
    axs[row, col].set_xlim(0, shape_width)
    axs[row, col].set_ylim(0, shape_height)
    axs[row, col].axis('off')  # 关闭子图的坐标轴

# 调整子图之间的间距
plt.tight_layout()

# 显示图形
plt.show()

# %% [markdown]
# ### <mark>調整2x3圖形比例<mark>

# %%
import matplotlib.pyplot as plt
import ast

# 假设你的数据字符串
data_str = '[{"label": "H7", "shape": [[1, 0, 1], [1, 1, 1], [1, 0, 1]], "order": "7", "color_hex": "#FF0000", "color_name": "red"}, {"label": "O6", "shape": [[1, 1, 1], [1, 1, 1]], "order": "6", "color_hex": "#DBFF2F", "color_name": "greenyellow"}, {"label": "F5", "shape": [[1, 1, 0], [0, 1, 1], [0, 1, 0]], "order": "5", "color_hex": "#EE82EE", "color_name": "violet"}, {"label": "Y5", "shape": [[1, 1, 1, 1], [0, 1, 0, 0]], "order": "5", "color_hex": "#00FF00", "color_name": "lime"}, {"label": "V5", "shape": [[1, 1, 1], [1, 0, 0], [1, 0, 0]], "order": "5", "color_hex": "#FFC0CB", "color_name": "pink"}, {"label": "U5", "shape": [[1, 0, 1], [1, 1, 1]], "order": "5", "color_hex": "#0000FF", "color_name": "blue"}, {"label": "N5", "shape": [[1, 1, 1, 0], [0, 0, 1, 1]], "order": "5", "color_hex": "#FF8C00", "color_name": "darkorange"}, {"label": "L5", "shape": [[1, 1, 1, 1], [1, 0, 0, 0]], "order": "5", "color_hex": "#008000", "color_name": "green"}, {"label": "Z5", "shape": [[1, 1, 0], [0, 1, 0], [0, 1, 1]], "order": "5", "color_hex": "#FFFF00", "color_name": "yellow"}, {"label": "O4", "shape": [[1, 1], [1, 1]], "order": "4", "color_hex": "#FFD700", "color_name": "gold"}, {"label": "T4", "shape": [[1, 1, 1], [0, 1, 0]], "order": "4", "color_hex": "#800080", "color_name": "purple"}, {"label": "Z4", "shape": [[1, 1, 0], [0, 1, 1]], "order": "4", "color_hex": "#00FFFF", "color_name": "cyan"}, {"label": "L4", "shape": [[1, 1, 1], [1, 0, 0]], "order": "4", "color_hex": "#00BFFF", "color_name": "deepskyblue"}]'

# 将字符串转换为字典列表
data_list = ast.literal_eval(data_str)

# 计算子图的行数和列数
num_rows = 4
num_cols = 4

# 检查数据列表长度是否大于子图数量
if len(data_list) > num_rows * num_cols:
    raise ValueError("数据列表中的图形数量超出了子图布局的总数！")

# 创建一个新的图形，指定子图布局
fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, 12))

# 遍历每个形状并绘制
for i, shape_info in enumerate(data_list):
    row = i // num_cols
    col = i % num_cols

    label = shape_info['label']
    shape = shape_info['shape']
    color_hex = shape_info['color_hex']

    # 提取形状大小
    shape_height = len(shape)
    shape_width = len(shape[0])

    # 计算每个矩形的实际大小
    rect_height = 1.0 / max(shape_height, shape_width)
    rect_width = 1.0 / max(shape_height, shape_width)

    # 绘制形状
    for j in range(shape_height):
        for k in range(shape_width):
            if shape[j][k] == 1:
                # 计算矩形左下角的坐标
                rect_bottom = 1 - (j + 1) * rect_height
                rect_left = k * rect_width
                # 绘制矩形并设置颜色
                axs[row, col].add_patch(plt.Rectangle((rect_left, rect_bottom), rect_width, rect_height, color=color_hex))
            else:
                # 如果为0，填充黑色
                rect_bottom = 1 - (j + 1) * rect_height
                rect_left = k * rect_width
                axs[row, col].add_patch(plt.Rectangle((rect_left, rect_bottom), rect_width, rect_height, color='black'))

    # 添加标签
    axs[row, col].text(0.5, 0.95, label, horizontalalignment='center', verticalalignment='top', transform=axs[row, col].transAxes)

    # 设置子图的坐标轴
    axs[row, col].set_xlim(0, 1)
    axs[row, col].set_ylim(0, 1)
    axs[row, col].axis('off')  # 关闭子图的坐标轴

# 调整子图之间的间距
plt.tight_layout()

# 显示图形
plt.show()

# %% [markdown]
# https://www.youtube.com/watch?v=jvPMyMe39fc
